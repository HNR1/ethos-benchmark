# %%
import pandas as pd
df = pd.read_parquet("/home/henri/ethos-benchmark/results/hospital_mortality/mimic_layer_6_do_0.3_recent_subset0.01_xzl337ud/rep_size_1_2026-09-17_15-14-57/samples_[0-3230).parquet")
df.iloc[:10:,:]
# Out:
#              expected              actual        stop_reason  actual_prob  \
# 0  HOSPITAL_DISCHARGE  HOSPITAL_DISCHARGE  token_of_interest     0.033688
# 1  HOSPITAL_DISCHARGE  HOSPITAL_DISCHARGE  token_of_interest     0.220218
# 2  HOSPITAL_DISCHARGE  HOSPITAL_DISCHARGE  token_of_interest     0.274680
# 3  HOSPITAL_DISCHARGE  HOSPITAL_DISCHARGE  token_of_interest     0.282660
# 4  HOSPITAL_DISCHARGE  HOSPITAL_DISCHARGE  token_of_interest     0.225388
# 5  HOSPITAL_DISCHARGE        TIMELINE_END  token_of_interest     0.000051
# 6  HOSPITAL_DISCHARGE  HOSPITAL_DISCHARGE  token_of_interest     0.765762
# 7  HOSPITAL_DISCHARGE  HOSPITAL_DISCHARGE  token_of_interest     0.009064
# 8  HOSPITAL_DISCHARGE  HOSPITAL_DISCHARGE  token_of_interest     0.430348
# 9  HOSPITAL_DISCHARGE  HOSPITAL_DISCHARGE  token_of_interest     0.052277
#
#    HOSPITAL_DISCHARGE    MEDS_DEATH  TIMELINE_END true_token_time  \
# 0        3.368809e-02  5.638326e-06  1.376756e-04 1 days 16:04:00
# ...

# %%
df.sort_values(by="patient_id", ascending=True).iloc[900:1000:5,10:]
# Out:
#       token_dist  patient_id     prediction_time  data_idx     hadm_id
# 2190           9    13007657 2137-03-25 16:28:00  23961849  25296178.0
# 2274         169    13023241 2187-10-20 11:30:00  23989335  21597109.0
# 1203           2    13032738 2176-06-11 17:20:00  24002473  25158536.0
# 177           21    13051530 2174-06-10 18:49:00  24038786  22420878.0
# 176            1    13051530 2174-06-10 18:49:00  24038786  22420878.0
# 2204          42    13060229 2117-09-01 14:49:00  24079427  21728260.0
# 2602          58    13078497 2122-08-16 15:40:00   5710548  20907701.0
# 2066           9    13086918 2148-11-25 17:31:00   5729584  22599347.0
# 831            2    13102401 2148-07-09 15:57:00  24138411  26772369.0
# 1098           1    13102762 2171-11-21 19:45:00  42168887  22835343.0
# 349           49    13122237 2150-09-22 16:39:00  24171519  25954980.0
# 1870           1    13166078 2191-07-04 16:50:00   5869772  24536151.0
# ...

# %%
df.shape
# Out:
# (3230, 16)

# %%
df[df.expected.str.contains("DEATH")].shape
# Out:
# (70, 16)
